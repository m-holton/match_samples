# %%
    '''
    
    
    Parameters
    ----------
    
    Returns
    -------
    '''
# Out:
# '\n\n\nParameters\n----------\n\nReturns\n-------\n'

# %%
'''
Created on Jun 24, 2018

@author: Mark Holton
'''

import sys


import pandas as pd
import numpy as np
from qiime2 import Metadata

print("start")
# Out:
# start

# %% [markdown]
# Comments are for code below
# Reads a text file in and converts it to a dataframe. Due to the large size of the file a smaller file is created with hard coded columns for testing.

# %%
#read the file in and
textfile = "./ag_map_with_alpha.txt"
originalDF=pd.read_csv(textfile,
                        sep = "\t")
masterDF = originalDF.copy()
masterDF_short=masterDF.loc[:,['#SampleID',  
                                            'age_years',    
                                            'antibiotic_history',    
                                            'bmi_cat',  
                                            'depression_bipolar_schizophrenia', 
                                            'mental_illness_type_depression', 
                                            'smoking_frequency']]#.set_index('#SampleID', drop = False)
masterDF = masterDF_short.copy()
# Out:
# /home/markholton/anaconda3/envs/qiime2-2018.6/lib/python3.5/site-packages/IPython/core/interactiveshell.py:2785: DtypeWarning: Columns (0,66) have mixed types. Specify dtype option on import or set low_memory=False.
#   interactivity=interactivity, compiler=compiler, result=result)

# %%
metadata = 'qiime2-sample-metadata.csv' 
metadataDF = Metadata.load( metadata ).to_dataframe()
metadataDF.dtypes
# Out:
# BarcodeSequence              object
# LinkerPrimerSequence         object
# BodySite                     object
# Year                        float64
# Month                       float64
# Day                         float64
# Subject                      object
# ReportedAntibioticUsage      object
# DaysSinceExperimentStart    float64
# Description                  object
# dtype: object

# %%
metadataDF.BodySite
# Out:
# #SampleID
# L1S8             gut
# L1S57            gut
# L1S76            gut
# L1S105           gut
# L2S155     left palm
# L2S175     left palm
# L2S204     left palm
# L2S222     left palm
# L3S242    right palm
# L3S294    right palm
# L3S313    right palm
# L3S341    right palm
# L3S360    right palm
# L5S104        tongue
# L5S155        tongue
# L5S174        tongue
# L5S203        tongue
# L5S222        tongue
# L1S140           gut
# L1S208           gut
# L1S257           gut
# L1S281           gut
# L2S240     left palm
# L2S309     left palm
# L2S357     left palm
# L2S382     left palm
# L3S378    right palm
# L4S63     right palm
# L4S112    right palm
# L4S137    right palm
# L5S240        tongue
# L6S20         tongue
# L6S68         tongue
# L6S93         tongue
# Name: BodySite, dtype: object

# %%
def get_user_input_exclude():
    '''
    converts user_input_exclude file into user_input_excludeDF dataframe
    
    user_input_exclude is the file that contains the data needed to determine what samples to exclude. The file is a 
    tab seperated. The first line has the names of columns to look at for each filter condition. The second line is 
    what type of filter. Keep means that any row that satisfies the condition layed out below will be kept. Exclude 
    means rows that satisfy the condition will be filtered out. Third line is the filter comparison type. It can be <, 
    >, <=, >=, or ==. The forth (and following lines if == is chosen) form the end of the comparison. 
    
    EX. If one column of the file is
    age_years
    keep
    <
    50
    
    then the program will keep and rows where age_years is less than 50.

    Parameters
    ----------
    none
    
    Returns
    -------
    user_input_excludeDF
        dataframe that contains the information in user_input_exclude file
    '''
    user_input_exclude = 'exclude' # input("Filename for file with column and data to exclude: ")
    user_input_exclude = './%s.txt'%(user_input_exclude)
    user_input_excludeDF = pd.read_csv(user_input_exclude, sep = "\t")
    return user_input_excludeDF

# %%
def get_user_input_control():
    '''
    converts user_input_control file into user_input_controlDF dataframe
    
    user_input_control is the file that contains the data needed to determine what samples should be labeled control. 
    The file is tab seperated. The first line has the names of columns to look at for labeling. The following lines 
    contain strings. If the data for the coresponding column in the sample dataframe matches any of the previously 
    mentioned strings, the sample is labeled control in the case_control column.
    
    Parameters
    ----------
    none
    
    Returns
    -------
    user_input_controlDF
        dataframe that contains the information in user_input_control file
    '''
    user_input_control = 'control' # input("Filename for file with column and data to determine control: ")
    user_input_control = './%s.txt'%(user_input_control)
    user_input_controlDF = pd.read_csv(user_input_control, sep = "\t")
    return user_input_controlDF

# %%
def get_user_input_experiment():
    '''
    converts user_input_experiment file into user_input_experimentDF dataframe
    
    user_input_experiment is the file that contains the data needed to determine what samples should be labeled case. 
    The file is tab seperated. The first line has the names of columns to look at for labeling.The following lines 
    contain strings. If the data for the coresponding column in the sample dataframe matches any of the previously 
    mentioned strings, the sample is labeled case in the case_control column.
    
    Parameters
    ----------
    none
    
    Returns
    -------
    user_input_experimentDF
        dataframe that contains the information in user_input_experiment file
    '''
    user_input_experiment = 'experiment' # input("Filename for file with column and data to determine experimental: ")
    user_input_experiment = './%s.txt'%(user_input_experiment )
    user_input_experimentDF = pd.read_csv(user_input_experiment, sep = "\t")
    return user_input_experimentDF

# %%
def get_user_input_match():
    '''
    converts user_input_match file into user_input_matchDF dataframe
    
    user_input_match is the file that contains the data needed to determine what case and control samples should 
    be matched on. The file is tab seperated. The first line has the names of columns that samples will be matched on. 
    The second line contains what data type its coresponding column contains in the dataframe of samples. 
    It can be string or number. The third line contain different information depending on which column of the file 
    they are in. Columns where line 3 was string will be blank since stings are matched exactly. Columns where line 3 
    was number will be a number. This number is how far away sample data can be for the given column to still be matched. 
    
    EX. if the file text was
    bmi_cat age_years smoking_frequency
    string number string
    5
    
    Then the case and control samples would be matched to have the same bmi_cat and smoking_frequency. 
    Samples would also have to come from individuals within a five year distance in age to be matched.

    Parameters
    ----------
    none
    
    Returns
    -------
    user_input_matchDF
        dataframe that contains the information in user_input_match file
    '''
    user_input_match = 'match' # input("Filename for file with columns, type of value, and offset if needed to match samples: ")
    user_input_match= './%s.txt'%(user_input_match)
    user_input_matchDF = pd.read_csv(user_input_match, sep = "\t")
    return user_input_matchDF

# %%
user_input_excludeDF = get_user_input_exclude()
user_input_controlDF = get_user_input_control()
user_input_experimentDF = get_user_input_experiment()
user_input_matchDF = get_user_input_match()

# %% [markdown]
# Filters out unwanted rows based on values in chosen columns.

# %%
def exclude_samples(masterDF, inputDF):
    '''
    Filters out unwanted rows based on values in chosen columns.
    
    Parameters
    ----------
    masterDF : dataframe
        dataframe with all samples that needs to have samples filtered out
    
    inputDF : dataframe'
        dataframe with information to determine what samples to be filtered out
    
    Returns
    -------
    excludeDF : dataframe
        dataframe with samples filtered out based on outcome of conditional statements
    '''
    
    rows_num , columns_num = inputDF.shape
    print('rows  = %s, columns = %s'%(rows_num, columns_num) )
    r_counter = 0
    c_counter = 0

    while c_counter < columns_num:
        # column to look at for determining exclution 
        column_name = inputDF.columns[c_counter] 
        # data satifies the conditional statements below should the data be kept of excluded
        keep_if_match = ( inputDF.loc[0,column_name] == 'keep' )
        # type of filter can be <= < == > >= 
        type_of_filter =  inputDF.loc[1,column_name]
        masterDF = masterDF[ masterDF[column_name].isin( ['Unspecified'] ) == False ]
        #conditional statements
        if type_of_filter == '==':
            masterDF = masterDF[
                    masterDF[column_name].isin( inputDF[column_name].tolist() ) 
                    == 
                    ( keep_if_match ) ]
        if type_of_filter == '<=':
            masterDF = masterDF[
                    ( pd.to_numeric(masterDF[column_name]) <= float(inputDF.loc[2,column_name]) ) 
                    == 
                    ( keep_if_match ) ]
        if type_of_filter == '>=':
            masterDF = masterDF[
                    ( pd.to_numeric(masterDF[column_name]) >= float(inputDF.loc[2,column_name]) ) 
                    == 
                    ( keep_if_match ) ]
        if type_of_filter == '<':
            masterDF = masterDF[
                    ( pd.to_numeric(masterDF[column_name]) < float(inputDF.loc[2,column_name]) ) 
                    == 
                    ( keep_if_match ) ]
        if type_of_filter == '>':    
            masterDF = masterDF[
                    ( pd.to_numeric(masterDF[column_name]) > float(inputDF.loc[2,column_name]) ) 
                    == 
                    ( keep_if_match ) ]
        if type_of_filter == '> <':    
            masterDF = masterDF[
                    ( 
                    pd.to_numeric(masterDF[column_name]) > float(inputDF.loc[2,column_name]) 
                    &
                    pd.to_numeric(masterDF[column_name]) < float(inputDF.loc[3,column_name])
                    ) 
                    == 
                    ( keep_if_match ) ]
        if type_of_filter == '>= <=':    
            masterDF = masterDF[
                    ( 
                    pd.to_numeric(masterDF[column_name]) >= float(inputDF.loc[2,column_name]) 
                    &
                    pd.to_numeric(masterDF[column_name]) <= float(inputDF.loc[3,column_name])
                    )
                    == 
                    ( keep_if_match ) ]
        if type_of_filter == '> <=':    
            masterDF = masterDF[
                    ( 
                    pd.to_numeric(masterDF[column_name]) > float(inputDF.loc[2,column_name]) 
                    &
                    pd.to_numeric(masterDF[column_name]) <= float(inputDF.loc[3,column_name])
                    ) 
                    == 
                    ( keep_if_match ) ]
        if type_of_filter == '>= <':    
            masterDF = masterDF[
                    ( 
                    pd.to_numeric(masterDF[column_name]) >= float(inputDF.loc[2,column_name]) 
                    &
                    pd.to_numeric(masterDF[column_name]) < float(inputDF.loc[3,column_name])
                    ) 
                    == 
                    ( keep_if_match ) ]

        #increment counter  
        c_counter = c_counter + 1

    return masterDF.copy()

# %%
excludeDF = exclude_samples(masterDF, user_input_excludeDF)
# Out:
# rows  = 5, columns = 2

# %% [markdown]
# Lables the samples based on if they are control or not

# %%
def filter_control_case(type_of_filter, column_name, masterDF, inputDF):
    ''' Lables the samples based on if they satisfy certain conditions
    
    Parameters
    ----------
    type_of_filter : str
        what way to compare inputDF values to masterDF
        can be <, >, ==, > <, <=, >=, <= >=, < >=, <= >
        == is the only one that can be used on string values
        
    column_name : str
        name of the column to look at for values. Only data in that column will be looked at. Must be the name of a 
        column in both masterDF and inputDF
        
    masterDF : panda dataframe
        dataframe of metadata for samples after exclutions are done
        
    inputDF : panda dataframe
        Can be user_input_control or user_input_experiment dataframes
        
    Returns
    -------
    masterDF 
        dataframe with column case_control labled to reflect if it satified the column_name and type_of_filter 
        conditional statements below
    '''

    
    # First checks to see if for the sample is already true for case_control. 
    if type_of_filter == '==':
        # Then check if for a column its value is in the list of values in the input dataframe.
        masterDF['case_control'] = np.where(masterDF['case_control'].isin([True]) 
                                            & 
                                            masterDF[column_name].isin( inputDF[column_name].tolist() ), 
                                            True, False)    
    # Then check if value in masterDF is "type_of_filter" corresponding value in inputDF
    if type_of_filter == '<=':
        masterDF['case_control'] = np.where(masterDF['case_control'].isin([True]) 
                                            & 
                                            ( pd.to_numeric(masterDF[column_name]) <= float(inputDF.loc[1,column_name]) ),
                                            True, False)           
    if type_of_filter == '>=':
        masterDF['case_control'] = np.where(masterDF['case_control'].isin([True]) 
                                            & 
                                            ( pd.to_numeric(masterDF[column_name]) >= float(inputDF.loc[1,column_name]) ),
                                            True, False)           
    if type_of_filter == '<': 
        masterDF['case_control'] = np.where(masterDF['case_control'].isin([True])                                        
                                            & 
                                            ( pd.to_numeric(masterDF[column_name]) < float(inputDF.loc[1,column_name]) ),
                                            True, False)           
    if type_of_filter == '>':    
        masterDF['case_control'] = np.where(masterDF['case_control'].isin([True]) 
                                            & 
                                            ( pd.to_numeric(masterDF[column_name]) > float(inputDF.loc[1,column_name]) ),
                                            True, False)      
    # Then check if value in masterDF is within the bounds (inclusively or not based on type_of_filter) of the numbers
    # in inputDF
    if type_of_filter == '> <':    
        masterDF['case_control'] = np.where(masterDF['case_control'].isin([True]) 
                                            & 
                                            ( pd.to_numeric(masterDF[column_name]) > float(inputDF.loc[1,column_name]) )
                                            &
                                            ( pd.to_numeric(masterDF[column_name]) < float(inputDF.loc[2,column_name]) ),
                                            True, False)           
    if type_of_filter == '>= <=':    
        masterDF['case_control'] = np.where(masterDF['case_control'].isin([True]) 
                                            & 
                                            ( pd.to_numeric(masterDF[column_name]) >= float(inputDF.loc[1,column_name]) )
                                            &
                                            ( pd.to_numeric(masterDF[column_name]) <= float(inputDF.loc[2,column_name]) ),
                                            True, False)          
    if type_of_filter == '> <=':    
        masterDF['case_control'] = np.where(masterDF['case_control'].isin([True]) 
                                            & 
                                            ( pd.to_numeric(masterDF[column_name]) > float(inputDF.loc[1,column_name]) )
                                            &
                                            ( pd.to_numeric(masterDF[column_name]) <= float(inputDF.loc[2,column_name]) ),
                                            True, False)
    if type_of_filter == '>= <':    
        masterDF['case_control'] = np.where(masterDF['case_control'].isin([True]) 
                                            & 
                                            ( pd.to_numeric(masterDF[column_name]) >= float(inputDF.loc[1,column_name]) )
                                            &
                                            ( pd.to_numeric(masterDF[column_name]) < float(inputDF.loc[2,column_name]) ),
                                            True, False)     
    
    return masterDF

# %%
def get_controlDF(masterDF, inputDF):
    '''
    Uses filter_control_case for each column in inputDF to label controls
    
    Parameters
    ----------
    masterDF : dataframe
        dataframe with unwanted samples filtered out
        
    inputDF : dataframe
        contains information required for a complete user_input_controlDF
        
    Returns
    -------
    controlDF : dataframe
        same as masterDF except samples are labeled by if they are control or not in a new column named case_control
    
    '''
    rows_num , columns_num = inputDF.shape
    print('rows  = %s, columns = %s'%(rows_num, columns_num) )
    r_counter = 0
    c_counter = 0
    #creates a new case_control column of the dataframe and sets all the values to false
    masterDF['case_control'] = True

    while c_counter < columns_num:
        column_name = inputDF.columns[c_counter]
        type_of_filter =  inputDF.loc[0,column_name]


        masterDF = filter_control_case(type_of_filter, column_name, masterDF, inputDF)


        #increment counter
        c_counter = c_counter + 1


    #replaces the true values created by the loop above to control
    masterDF['case_control'] = masterDF['case_control'].replace(True, 'control')   
    #replaces the false values created by the loop above to Unspecified
    masterDF['case_control'] = masterDF['case_control'].replace(False, 'Unspecified' )

    return masterDF.copy()

# %%
controlDF = get_controlDF(excludeDF.copy(), user_input_controlDF.copy())
#controlDF
# Out:
# rows  = 3, columns = 2

# %% [markdown]
# Lables the samples based on if they are cases or not

# %%
def get_caseDF(masterDF, inputDF):
    '''
    labels case samples in a new case_control column
    
    Parameters
    ----------
    masterDF : dataframe
        dataframe with unwanted samples filtered out

    inputDF : dataframe
        contains information required for a complete user_input_experimentDF
    
    Returns
    -------
    caseDF : dataframe
        same as masterDF except samples are labeled by if they are control or not in a new column named case_control

    Notes
    -----
    masterDF should be the same for both get_caseDF and get_controlDF
    
    '''
    rows_num , columns_num = inputDF.shape
    print('rows  = %s, columns = %s'%(rows_num, columns_num) )
    r_counter = 0
    c_counter = 0

    #creates a new case_control column of the dataframe and sets all the values to false
    masterDF['case_control'] = True

    while c_counter < columns_num:
        column_name = inputDF.columns[c_counter]
        type_of_filter =  inputDF.loc[0,column_name]


        masterDF = filter_control_case(type_of_filter, column_name, masterDF, inputDF)


        #increment counter
        c_counter = c_counter + 1

    #replaces the true values created by the loop above to case
    masterDF['case_control'] = masterDF['case_control'].replace(True, 'case')   
    #replaces the false values created by the loop above to Unspecified
    masterDF['case_control'] = masterDF['case_control'].replace(False, 'Unspecified')

    return masterDF.copy()

# %%
caseDF = get_caseDF( excludeDF.copy(), user_input_experimentDF.copy() )
# Out:
# rows  = 4, columns = 2

# %%
def merge_caseDF_and_controlDF(caseDF, controlDF):
    '''
    Combines the two case_control columns into one column using pandas.DataFrame.where. Then makes this the master 
    dataframe's case_control column. The case column is layed on first and any values not equal to case are assigned 
    its value in controlDF
    
    Parameters
    ----------
    caseDF : dataframe
        outputed dataframe of get_caseDF
        
    controlDF : dataframe
        outputed dataframe of get_controlDF
        
    Returns
    -------
    case_controlDF : dataframe
        masterDF with case_control reflecting a combination of control and case
    
    '''
    #makes the case control column equal to is value in controlDF dataframe unless it is case in the experDF dataframe
    masterDF['case_control'] = caseDF['case_control'].where( 
                                                            caseDF['case_control'].isin(['case']), 
                                                            controlDF['case_control'])

    return masterDF.copy()

# %%
case_controlDF = merge_caseDF_and_controlDF(caseDF, controlDF)

# %% [markdown]
# Filters out data with match columns left unspecified

# %%
def filter_prep_for_matchDF(non_filteredDF, inputDF):
    '''
    filters out samples that do not have valid entries for columns that determine matching
    
    Parameters
    ----------
    non_filteredDF : dataframe
        has case_control with correct labels but some samples might not have all matching information
    
    inputDF : dataframe
        contains information required for a complete user_input_matchDF

    Returns
    -------
    match_filteredDF : dataframe
        Samples that do not have valid entries for columns that determine matching are removed. Everything else is the
        same as non_filteredDF
    '''
    rows_num , columns_num = inputDF.shape
    print('rows  = %s, columns = %s'%(rows_num, columns_num) )
    r_counter = 0
    c_counter = 0
    while c_counter < columns_num:
            column_name = inputDF.columns[c_counter]
            # only keep samples where for the chosen columns no values equal Unspecified
            non_filteredDF = non_filteredDF.where(non_filteredDF[column_name] != 'Unspecified')
            c_counter = c_counter + 1
    non_filteredDF = non_filteredDF.dropna()
    #masterDF = masterDF.reset_index(drop=True)


    return non_filteredDF.copy()

# %%
      
match_filteredDF = filter_prep_for_matchDF(case_controlDF.copy(), user_input_matchDF.copy())
# Out:
# rows  = 2, columns = 3

# %% [markdown]
# Sets the matched to column of master_frame to the case sample (case_row) ID for the control samples still left in match_frame

# %%
def match_to_master(master_frame, match_frame, case_index, case_row):
    '''
    Labels control samples with what case sample they match to in the matched to column
    
    Parameters
    ----------
    master_frame : dataframe
        what will have its matched to column changed
    match_frame : dataframe
        contains the samples that match to case_row
    case_index : integer
        index of case_row in master_frame
    case_row : series?
        case sample that matches to samples in match_frame

    Returns
    -------
    master_frame
        output is the updated master_frame with matched to column reflecting the case id number it matches to for controls
        and cases are labeled 1 in matched to column
    '''
    for index, row in match_frame.iterrows():
        #print(master_frame.at[index, 'matched to'] )
        master_frame.at[index, 'matched to'] = str(case_row['#SampleID']) 
        #sets the case sample matched to value to 1 in master_frame
        master_frame.at[case_index, 'matched to'] = '1'#best match place holder'
    
    
    return master_frame

# %% [markdown]
# Matches samples labled experiment to control samples

# %%
def match_samples(masterDF, inputDF):
    '''
    matches case samples to controls and puts the case's id in column matched to on the control sample's row
    
    Parameters
    ----------
    masterDF : dataframe
        dataframe with noncomplete samples filtered out
    
    inputDF : dataframe
        contains information required for a complete user_input_matchDF
    
    Returns
    -------
    masterDF : dataframe
        masterDF with matches represented by a column called matched to. Values in matched to are sample id of the case
        sample the control sample matches to or 1 if it is a case sample
    
    '''
    
    rows_num , columns_num = inputDF.shape
    print('rows  = %s, columns = %s'%(rows_num, columns_num) )
    # creates row and column counters
    r_counter = 0
    c_counter = 0

    case_for_matchDF = masterDF[masterDF['case_control'].isin(['case'])]
    # creates column to show matches. since it will contain the sample number it was matched too the null value will be 0
    masterDF['matched to'] = '0'

    matchDF = masterDF.copy()

    # loops though case samples and matches them to controls
    for index, row in case_for_matchDF.iterrows():
        # set matchDF to be only the samples of masterDF that are control samples
        matchDF = masterDF.copy()
        matchDF = matchDF[matchDF['case_control'].isin(['control'])]

        # loop though input columns to determine matches
        #print(index)
        c_counter = 0
        while c_counter < columns_num:
            column_name = inputDF.columns[c_counter]
            # get the type of data for the given column. This determine how a match is determined
            datatype = inputDF.iloc[0,c_counter]
            if datatype == 'string':
                # filters controls if the strings for the control and case don't match
                matchDF = matchDF[matchDF[column_name].isin([ row[column_name] ]) ]
            if datatype == 'number':
                # filters controls based on if the value in the control is not within a given distance form the case
                matchDF = matchDF[
                                    ( pd.to_numeric(matchDF[column_name]) >= ( int(float(row[column_name])) - int(float(inputDF.iloc[1,c_counter])) ) ) 
                                    &
                                    ( pd.to_numeric(matchDF[column_name]) <= ( int(float(row[column_name])) + int(float(inputDF.iloc[1,c_counter])) ) )
                                   ] 
            # increment loop counter
            c_counter = c_counter + 1

        # sets the matched to column of masterDF to the case sample ID for the control samples still left in matchDF
        masterDF = match_to_master(masterDF, matchDF, index, row)

    
    return masterDF.copy()

# %%
masterDF = match_samples( match_filteredDF.copy(), user_input_matchDF.copy() )
# Out:
# rows  = 2, columns = 3

# %%
masterDF['matched to'].unique()
# Out:
# array(['0', '10317.000023089', '1', '10317.000016325', '10317.000031285',
#        '10317.000029311', '10317.000030278'], dtype=object)

# %%
masterDF
# Out:
#             #SampleID age_years  \
# 1     10317.000049761        52
# 4     10317.000030322      43.0
# 6     10317.000028857      56.0
# 8     10317.000038189      39.0
# 10    10317.000036487      46.0
# 11    10317.000030166      58.0
# 12    10317.000023295      56.0
# 13    10317.000001589      58.0
# 16    10317.000021163      56.0
# 20    10317.000029448      44.0
# 21    10317.000031342      55.0
# 26    10317.000017750      57.0
# 27    10317.000020516      51.0
# 28    10317.000012512        33
# 31    10317.000071409        30
# 33    10317.000041539      50.0
# 34    10317.000017650      58.0
# 37    10317.000010102      33.0
# 38    10317.000003983      59.0
# 39    10317.000020722      47.0
# 41    10317.000011162      38.0
# 42    10317.000032631      41.0
# 43    10317.000046285        27
# 45    10317.000036877      37.0
# 48    10317.000030018      43.0
# 52    10317.000010940      57.0
# 53    10317.000031575      60.0
# 59    10317.000035380      45.0
# 60    10317.000023927      60.0
# 61    10317.000067486        42
# ...               ...       ...
# 7647            10317      47.0
# 7650            10317        55
# 7652            10317      56.0
# 7653            10317      47.0
# 7657            10317        60
# 7661            10317      47.0
# 7662            10317        59
# 7664            10317      60.0
# 7666            10317        27
# 7667            10317      52.0
# 7668            10317      24.0
# 7671            10317      40.0
# 7672            10317      23.0
# 7673            10317      39.0
# 7675            10317      48.0
# 7677            10317      50.0
# 7678            10317      52.0
# 7681            10317      34.0
# 7682            10317        37
# 7684            10317      58.0
# 7686            10317      49.0
# 7689            10317      46.0
# 7692            10317      35.0
# 7699            10317      27.0
# 7700            10317      40.0
# 7701            10317      57.0
# 7705            10317      54.0
# 7706            10317        58
# 7708            10317      55.0
# 7709            10317      54.0
#
#                                   antibiotic_history      bmi_cat  \
# 1     I have not taken antibiotics in the past year.   Overweight
# 4     I have not taken antibiotics in the past year.       Normal
# 6     I have not taken antibiotics in the past year.   Overweight
# 8     I have not taken antibiotics in the past year.   Overweight
# 10    I have not taken antibiotics in the past year.        Obese
# 11    I have not taken antibiotics in the past year.   Overweight
# 12    I have not taken antibiotics in the past year.       Normal
# 13    I have not taken antibiotics in the past year.       Normal
# 16    I have not taken antibiotics in the past year.       Normal
# 20    I have not taken antibiotics in the past year.       Normal
# 21    I have not taken antibiotics in the past year.   Overweight
# 26    I have not taken antibiotics in the past year.        Obese
# 27    I have not taken antibiotics in the past year.       Normal
# 28    I have not taken antibiotics in the past year.  Underweight
# 31    I have not taken antibiotics in the past year.        Obese
# 33    I have not taken antibiotics in the past year.   Overweight
# 34    I have not taken antibiotics in the past year.       Normal
# 37    I have not taken antibiotics in the past year.       Normal
# 38    I have not taken antibiotics in the past year.        Obese
# 39    I have not taken antibiotics in the past year.       Normal
# 41    I have not taken antibiotics in the past year.       Normal
# 42    I have not taken antibiotics in the past year.       Normal
# 43    I have not taken antibiotics in the past year.       Normal
# 45    I have not taken antibiotics in the past year.       Normal
# 48    I have not taken antibiotics in the past year.       Normal
# 52    I have not taken antibiotics in the past year.       Normal
# 53    I have not taken antibiotics in the past year.   Overweight
# 59    I have not taken antibiotics in the past year.   Overweight
# 60    I have not taken antibiotics in the past year.  Underweight
# 61    I have not taken antibiotics in the past year.       Normal
# ...                                              ...          ...
# 7647  I have not taken antibiotics in the past year.       Normal
# 7650  I have not taken antibiotics in the past year.       Normal
# 7652  I have not taken antibiotics in the past year.        Obese
# 7653  I have not taken antibiotics in the past year.       Normal
# 7657  I have not taken antibiotics in the past year.       Normal
# 7661  I have not taken antibiotics in the past year.       Normal
# 7662  I have not taken antibiotics in the past year.  Underweight
# 7664  I have not taken antibiotics in the past year.       Normal
# 7666  I have not taken antibiotics in the past year.   Overweight
# 7667  I have not taken antibiotics in the past year.       Normal
# 7668  I have not taken antibiotics in the past year.   Overweight
# 7671  I have not taken antibiotics in the past year.       Normal
# 7672  I have not taken antibiotics in the past year.       Normal
# 7673  I have not taken antibiotics in the past year.       Normal
# 7675  I have not taken antibiotics in the past year.       Normal
# 7677  I have not taken antibiotics in the past year.       Normal
# 7678  I have not taken antibiotics in the past year.       Normal
# 7681  I have not taken antibiotics in the past year.       Normal
# 7682  I have not taken antibiotics in the past year.       Normal
# 7684  I have not taken antibiotics in the past year.       Normal
# 7686  I have not taken antibiotics in the past year.   Overweight
# 7689  I have not taken antibiotics in the past year.   Overweight
# 7692  I have not taken antibiotics in the past year.       Normal
# 7699  I have not taken antibiotics in the past year.       Normal
# 7700  I have not taken antibiotics in the past year.       Normal
# 7701  I have not taken antibiotics in the past year.   Overweight
# 7705  I have not taken antibiotics in the past year.       Normal
# 7706  I have not taken antibiotics in the past year.       Normal
# 7708  I have not taken antibiotics in the past year.   Overweight
# 7709  I have not taken antibiotics in the past year.   Overweight
#
#                        depression_bipolar_schizophrenia  \
# 1                                           Unspecified
# 4                          I do not have this condition
# 6                          I do not have this condition
# 8                                           Unspecified
# 10                         I do not have this condition
# 11                         I do not have this condition
# 12                         I do not have this condition
# 13                                          Unspecified
# 16                         I do not have this condition
# 20                                       Self-diagnosed
# 21                         I do not have this condition
# 26                                          Unspecified
# 27                         I do not have this condition
# 28                                          Unspecified
# 31                                          Unspecified
# 33                                          Unspecified
# 34                                          Unspecified
# 37                         I do not have this condition
# 38                                          Unspecified
# 39                         I do not have this condition
# 41                                          Unspecified
# 42                                          Unspecified
# 43                                          Unspecified
# 45                         I do not have this condition
# 48                         I do not have this condition
# 52                                          Unspecified
# 53                         I do not have this condition
# 59                         I do not have this condition
# 60                         I do not have this condition
# 61                                          Unspecified
# ...                                                 ...
# 7647                                        Unspecified
# 7650                                        Unspecified
# 7652                                        Unspecified
# 7653                       I do not have this condition
# 7657                                        Unspecified
# 7661                       I do not have this condition
# 7662                                        Unspecified
# 7664                       I do not have this condition
# 7666                                        Unspecified
# 7667                                        Unspecified
# 7668                       I do not have this condition
# 7671                                        Unspecified
# 7672                                        Unspecified
# 7673  Diagnosed by a medical professional (doctor, p...
# 7675                                        Unspecified
# 7677                                        Unspecified
# 7678                       I do not have this condition
# 7681                                        Unspecified
# 7682                                        Unspecified
# 7684                                        Unspecified
# 7686  Diagnosed by a medical professional (doctor, p...
# 7689                                        Unspecified
# 7692  Diagnosed by a medical professional (doctor, p...
# 7699                                     Self-diagnosed
# 7700                                        Unspecified
# 7701                                        Unspecified
# 7705                                        Unspecified
# 7706                                        Unspecified
# 7708                                        Unspecified
# 7709                                        Unspecified
#
#      mental_illness_type_depression           smoking_frequency case_control  \
# 1                       Unspecified                       Never  Unspecified
# 4                       Unspecified                       Never      control
# 6                       Unspecified                       Never  Unspecified
# 8                       Unspecified                       Never      control
# 10                      Unspecified                       Never  Unspecified
# 11                      Unspecified                       Never  Unspecified
# 12                      Unspecified                       Never  Unspecified
# 13                      Unspecified                       Never  Unspecified
# 16                      Unspecified                       Never  Unspecified
# 20                      Unspecified                       Never         case
# 21                      Unspecified                       Never  Unspecified
# 26                      Unspecified                       Never  Unspecified
# 27                      Unspecified                       Never  Unspecified
# 28                      Unspecified                       Never      control
# 31                      Unspecified                       Never  Unspecified
# 33                      Unspecified                       Never  Unspecified
# 34                      Unspecified                       Never  Unspecified
# 37                      Unspecified                       Never      control
# 38                      Unspecified                       Never  Unspecified
# 39                      Unspecified                       Never  Unspecified
# 41                      Unspecified                       Never      control
# 42                      Unspecified  Rarely (a few times/month)      control
# 43                      Unspecified                       Never  Unspecified
# 45                      Unspecified                       Never      control
# 48                      Unspecified                       Never      control
# 52                      Unspecified                       Never  Unspecified
# 53                      Unspecified                       Never  Unspecified
# 59                      Unspecified                       Never  Unspecified
# 60                      Unspecified                       Never  Unspecified
# 61                      Unspecified                       Never      control
# ...                             ...                         ...          ...
# 7647                    Unspecified                       Never  Unspecified
# 7650                            Yes                       Never  Unspecified
# 7652                    Unspecified                       Never  Unspecified
# 7653                    Unspecified                       Never  Unspecified
# 7657                    Unspecified                       Never  Unspecified
# 7661                    Unspecified                       Never  Unspecified
# 7662                    Unspecified                       Never  Unspecified
# 7664                    Unspecified                       Never  Unspecified
# 7666                    Unspecified  Rarely (a few times/month)  Unspecified
# 7667                    Unspecified                       Never  Unspecified
# 7668                    Unspecified  Rarely (a few times/month)  Unspecified
# 7671                    Unspecified                       Never      control
# 7672                    Unspecified                       Never  Unspecified
# 7673                    Unspecified                       Never  Unspecified
# 7675                    Unspecified                       Never  Unspecified
# 7677                    Unspecified                       Never  Unspecified
# 7678                    Unspecified                       Never  Unspecified
# 7681                    Unspecified                       Never      control
# 7682                    Unspecified                       Never      control
# 7684                    Unspecified                       Never  Unspecified
# 7686                    Unspecified                       Never         case
# 7689                    Unspecified                       Never  Unspecified
# 7692                    Unspecified                       Never  Unspecified
# 7699                    Unspecified                       Never  Unspecified
# 7700                    Unspecified                       Never      control
# 7701                    Unspecified                       Never  Unspecified
# 7705                    Unspecified                       Never  Unspecified
# 7706                    Unspecified                       Never  Unspecified
# 7708                    Unspecified                       Never  Unspecified
# 7709                    Unspecified  Rarely (a few times/month)  Unspecified
#
#            matched to
# 1                   0
# 4     10317.000023089
# 6                   0
# 8                   0
# 10                  0
# 11                  0
# 12                  0
# 13                  0
# 16                  0
# 20                  1
# 21                  0
# 26                  0
# 27                  0
# 28                  0
# 31                  0
# 33                  0
# 34                  0
# 37                  0
# 38                  0
# 39                  0
# 41                  0
# 42                  0
# 43                  0
# 45                  0
# 48    10317.000023089
# 52                  0
# 53                  0
# 59                  0
# 60                  0
# 61    10317.000023089
# ...               ...
# 7647                0
# 7650                0
# 7652                0
# 7653                0
# 7657                0
# 7661                0
# 7662                0
# 7664                0
# 7666                0
# 7667                0
# 7668                0
# 7671  10317.000023089
# 7672                0
# 7673                0
# 7675                0
# 7677                0
# 7678                0
# 7681                0
# 7682                0
# 7684                0
# 7686                0
# 7689                0
# 7692                0
# 7699                0
# 7700  10317.000023089
# 7701                0
# 7705                0
# 7706                0
# 7708                0
# 7709                0
#
# [3300 rows x 9 columns]
